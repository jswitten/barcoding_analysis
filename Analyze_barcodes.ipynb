# %%
from Bio import SeqIO
import pandas as pd
import os
import numpy as np
from Generic_barcode_quantification import read_to_raw_barcode, compile_experiment
from Generic_barcode_quantification import raw_barcode_loc, read_to_tagged_barcode, read_records_to_raw_barcode_dict
from Bio.Seq import Seq
from collections import Counter

# %%
# To do analysis without UMI (include_UMI = True)
all_dict = compile_experiment('Directory_here',
                              raw_barcodes_only = False, include_umi = True,
                              write_umi = False, write_bc_umi_count_dict = False, shorten = False, cheat_loc_tests = 10000)

# To do analysis without UMI (include_UMI = False)
all_dict = compile_experiment('Directory_here/',
                              raw_barcodes_only = False, include_umi = False,
                              write_umi = False, write_bc_umi_count_dict = False, shorten = False, cheat_loc_tests = 10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e90fcfd938b3> in <module>
#       1 # To do analysis without UMI (include_UMI = True)
# ----> 2 all_dict = compile_experiment('Directory_here',
#       3                               raw_barcodes_only = False, include_umi = True,
#       4                               write_umi = False, write_bc_umi_count_dict = False, shorten = False, cheat_loc_tests = 10000)
#       5
#
# NameError: name 'compile_experiment' is not defined
